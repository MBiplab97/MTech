# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sms
from datetime import datetime

# %%
df=pd.read_csv('TATAMOTORS_data.csv')

# %%
df.head(3)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-11-15  414.299988  417.549988  407.000000  408.649994  408.649994
# 1  2017-11-16  411.350006  415.899994  411.350006  413.450012  413.450012
# 2  2017-11-17  419.450012  423.450012  417.000000  421.799988  421.799988
#
#     Volume
# 0  9867270
# 1  6291441
# 2  6191428

# %%
df.tail(3)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 1230  2022-11-09  439.200012  441.200012  432.000000  433.149994  433.149994
# 1231  2022-11-10  420.500000  420.549988  409.200012  412.200012  412.200012
# 1232  2022-11-11  420.000000  425.500000  414.700012  423.500000  423.500000
#
#         Volume
# 1230  14471443
# 1231  26251660
# 1232  19296401

# %%
df.set_index('Date', inplace=True)
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-11-15  414.299988  417.549988  407.000000  408.649994  408.649994
# 2017-11-16  411.350006  415.899994  411.350006  413.450012  413.450012
# 2017-11-17  419.450012  423.450012  417.000000  421.799988  421.799988
# 2017-11-20  421.000000  425.700012  420.100006  423.000000  423.000000
# 2017-11-21  424.450012  430.000000  422.500000  424.250000  424.250000
# ...                ...         ...         ...         ...         ...
# 2022-11-04  418.200012  426.000000  416.899994  425.350006  425.350006
# 2022-11-07  428.250000  437.500000  428.250000  435.000000  435.000000
# 2022-11-09  439.200012  441.200012  432.000000  433.149994  433.149994
# 2022-11-10  420.500000  420.549988  409.200012  412.200012  412.200012
# 2022-11-11  420.000000  425.500000  414.700012  423.500000  423.500000
#
#               Volume
# Date
# 2017-11-15   9867270
# 2017-11-16   6291441
# 2017-11-17   6191428
# 2017-11-20   4051153
# 2017-11-21   6745407
# ...              ...
# 2022-11-04  12277023
# 2022-11-07  15058076
# 2022-11-09  14471443
# 2022-11-10  26251660
# 2022-11-11  19296401
#
# [1233 rows x 6 columns]

# %%
# make it datetime format
df.index = pd.to_datetime(df.index, format = '%Y/%m/%d')

# %%
df.head(3)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-11-15  414.299988  417.549988  407.000000  408.649994  408.649994
# 2017-11-16  411.350006  415.899994  411.350006  413.450012  413.450012
# 2017-11-17  419.450012  423.450012  417.000000  421.799988  421.799988
#
#              Volume
# Date
# 2017-11-15  9867270
# 2017-11-16  6291441
# 2017-11-17  6191428

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1233 entries, 2017-11-15 to 2022-11-11
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1233 non-null   float64
#  1   High       1233 non-null   float64
#  2   Low        1233 non-null   float64
#  3   Close      1233 non-null   float64
#  4   Adj Close  1233 non-null   float64
#  5   Volume     1233 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 67.4 KB

# %%
df.shape
# Out:
# (1233, 6)

# %%
df.plot(figsize=(10,3))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Close'].plot(figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df[['High','Close']].plot(figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Close'].plot(xlim=['2020-01-01','2022-09-01'],ylim=[0,1000],figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.index
# Out:
# DatetimeIndex(['2017-11-15', '2017-11-16', '2017-11-17', '2017-11-20',
#                '2017-11-21', '2017-11-22', '2017-11-23', '2017-11-24',
#                '2017-11-27', '2017-11-28',
#                ...
#                '2022-10-28', '2022-10-31', '2022-11-01', '2022-11-02',
#                '2022-11-03', '2022-11-04', '2022-11-07', '2022-11-09',
#                '2022-11-10', '2022-11-11'],
#               dtype='datetime64[ns]', name='Date', length=1233, freq=None)

# %% [markdown]
# # Time Resampling

# %%
df.resample(rule='A').min() 
#It gives us MIN values of all parameters in each year.
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017
# 2019-01-01  102256857
# 2019-04-01  100834335
# 2019-07-01   96568372
# 2019-10-01  184435614
# 2020-01-01  143550830
# 2020-04-01  215476711
# 2020-07-01  197510376
# 2020-10-01  171801183
# 2021-01-01  390577839
# 2021-04-01  119407026
# 2021-07-01  164083830
# 2021-10-01  197949387
# 2022-01-03   59776817
# 2022-04-01   71425747
# 2022-07-01   43084536
# 2022-10-03   32914630

# %%
##plotting
df['Close'].resample(rule='A').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# RULE M : monthly data
df['Close'].resample(rule='M').max().plot(kind='bar',figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Close'].rolling(11).mean().head(20)
# Out:
# Date
# 2017-11-15           NaN
# 2017-11-16           NaN
# 2017-11-17           NaN
# 2017-11-20           NaN
# 2017-11-21           NaN
# 2017-11-22           NaN
# 2017-11-23           NaN
# 2017-11-24           NaN
# 2017-11-27           NaN
# 2017-11-28           NaN
# 2017-11-29    420.254547
# 2017-11-30    419.845456
# 2017-12-01    418.522727
# 2017-12-04    416.872728
# 2017-12-05    414.986364
# 2017-12-06    412.513636
# 2017-12-07    410.095453
# 2017-12-08    408.722726
# 2017-12-11    407.327271
# 2017-12-12    406.004544
# Name: Close, dtype: float64

# %%
df['Close'].rolling(11).max().head(20)
# Out:
# Date
# 2017-11-15           NaN
# 2017-11-16           NaN
# 2017-11-17           NaN
# 2017-11-20           NaN
# 2017-11-21           NaN
# 2017-11-22           NaN
# 2017-11-23           NaN
# 2017-11-24           NaN
# 2017-11-27           NaN
# 2017-11-28           NaN
# 2017-11-29    428.600006
# 2017-11-30    428.600006
# 2017-12-01    428.600006
# 2017-12-04    428.600006
# 2017-12-05    428.600006
# 2017-12-06    428.600006
# 2017-12-07    426.250000
# 2017-12-08    425.500000
# 2017-12-11    421.399994
# 2017-12-12    415.950012
# Name: Close, dtype: float64

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-11-15  414.299988  417.549988  407.000000  408.649994  408.649994
# 2017-11-16  411.350006  415.899994  411.350006  413.450012  413.450012
# 2017-11-17  419.450012  423.450012  417.000000  421.799988  421.799988
# 2017-11-20  421.000000  425.700012  420.100006  423.000000  423.000000
# 2017-11-21  424.450012  430.000000  422.500000  424.250000  424.250000
#
#              Volume
# Date
# 2017-11-15  9867270
# 2017-11-16  6291441
# 2017-11-17  6191428
# 2017-11-20  4051153
# 2017-11-21  6745407

# %%
# simple moving average
df['Close:2 days rolling']=df['Close'].rolling(2).mean()
df['Close:5 days rolling']=df['Close'].rolling(5).mean()
df['Close:7 days rolling']=df['Close'].rolling(7).mean()
df['Close:10 days rolling']=df['Close'].rolling(10).mean()
df['Close:30 days rolling']=df['Close'].rolling(30).mean()
df['Close:50 days rolling']=df['Close'].rolling(50).mean()

# %%
df.head(31)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017
# 2017-12-22   5345261            421.399994            418.259998
# 2017-12-26   3700655            423.100006            421.940002
# 2017-12-27   3673355            423.325012            422.410004
# 2017-12-28   5018893            420.525009            421.610004
#
#             Close:7 days rolling  Close:10 days rolling  \
# Date
# 2017-11-15                   NaN                    NaN
# 2017-11-16                   NaN                    NaN
# 2017-11-17                   NaN                    NaN
# 2017-11-20                   NaN                    NaN
# 2017-11-21                   NaN                    NaN
# 2017-11-22                   NaN                    NaN
# 2017-11-23            420.857143                    NaN
# 2017-11-24            423.264287                    NaN
# 2017-11-27            424.399998                    NaN
# 2017-11-28            423.564287             420.885001
# 2017-11-29            422.271432             421.415002
# 2017-11-30            419.400003             420.485001
# 2017-12-01            415.157144             418.195001
# 2017-12-04            411.928571             416.260001
# 2017-12-05            408.607143             414.060001
# 2017-12-06            405.128571             410.904999
# 2017-12-07            403.135712             408.479999
# 2017-12-08            402.735709             407.044998
# 2017-12-11            403.592852             405.919998
# 2017-12-12            404.728568             405.009998
# 2017-12-13            404.485713             403.809998
# 2017-12-14            404.507141             403.634998
# 2017-12-15            405.657144             404.254999
# 2017-12-18            406.199999             404.469998
# 2017-12-19            407.478572             406.254999
# 2017-12-20            409.257145             408.810001
# 2017-12-21            411.250000             410.689999
# 2017-12-22            414.114284             411.775000
# 2017-12-26            417.228572             413.180002
# 2017-12-27            419.707145             414.740002
# 2017-12-28            421.535719             416.405002
#
#             Close:30 days rolling  Close:50 days rolling
# Date
# 2017-11-15                    NaN                    NaN
# 2017-11-16                    NaN                    NaN
# 2017-11-17                    NaN                    NaN
# 2017-11-20                    NaN                    NaN
# 2017-11-21                    NaN                    NaN
# 2017-11-22                    NaN                    NaN
# 2017-11-23                    NaN                    NaN
# 2017-11-24                    NaN                    NaN
# 2017-11-27                    NaN                    NaN
# 2017-11-28                    NaN                    NaN
# 2017-11-29                    NaN                    NaN
# 2017-11-30                    NaN                    NaN
# 2017-12-01                    NaN                    NaN
# 2017-12-04                    NaN                    NaN
# 2017-12-05                    NaN                    NaN
# 2017-12-06                    NaN                    NaN
# 2017-12-07                    NaN                    NaN
# 2017-12-08                    NaN                    NaN
# 2017-12-11                    NaN                    NaN
# 2017-12-12                    NaN                    NaN
# 2017-12-13                    NaN                    NaN
# 2017-12-14                    NaN                    NaN
# 2017-12-15                    NaN                    NaN
# 2017-12-18                    NaN                    NaN
# 2017-12-19                    NaN                    NaN
# 2017-12-20                    NaN                    NaN
# 2017-12-21                    NaN                    NaN
# 2017-12-22                    NaN                    NaN
# 2017-12-26                    NaN                    NaN
# 2017-12-27             413.545000                    NaN
# 2017-12-28             413.876667                    NaN

# %%
df[['Close','Close:2 days rolling']].plot(xlim=['2022-09-01','2022-11-11'],figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df[['Close','Close:5 days rolling']].plot(xlim=['2022-09-01','2022-11-11'],figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df[['Close','Close:7 days rolling']].plot(xlim=['2022-09-01','2022-11-11'],figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df[['Close','Close:10 days rolling']].plot(xlim=['2022-09-01','2022-11-11'],figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df[['Close','Close:30 days rolling']].plot(xlim=['2022-09-01','2022-11-11'],figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df[['Close','Close:50 days rolling']].plot(xlim=['2022-09-01','2022-11-11'],figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df[['Close','Close:10 days rolling','Close:30 days rolling','Close:50 days rolling']].plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [raw]
# Smoothing curve tells us when to buy and when to sell stock

# %%
# cumulative moving average(here I use for only open stock)
# use expanding
df['Close'].expanding().mean().plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#  exponential moving average
df['EMA_0.1'] = df['Close'].ewm(alpha=0.1, adjust=False).mean()
df['EMA_0.3'] = df['Close'].ewm(alpha=0.3, adjust=False).mean()

# %%
df[['Close','EMA_0.1']].plot(xlim=['2020-01-01','2022-01-01'],figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df[['Close','EMA_0.1','EMA_0.3']].plot(xlim=['2020-01-01','2022-01-01'],figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # STAT MODEL WITH ARIMA

# %%
# since it is seasonal data we are going to use dickey fuller test
from statsmodels.tsa.stattools import adfuller

# %%
# H0 : It is not stationary
# H1 : It is stationary

# %%
def adf_test(series):
    result=adfuller(series)
    print('ADF Statistics: {}'.format(result[0]))
    print('p- value: {}'.format(result[1]))
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %% [markdown]
# #strong evidence against the null hypothesis, reject the null hypothesis.
# #Data has no unit root and is stationary
#
# #weak evidence against null hypothesis, time series has a unit root,
# #indicating it is non-stationary

# %%
df1=pd.read_csv('TATAMOTORS_data.csv')
df1.head(3)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-11-15  414.299988  417.549988  407.000000  408.649994  408.649994
# 1  2017-11-16  411.350006  415.899994  411.350006  413.450012  413.450012
# 2  2017-11-17  419.450012  423.450012  417.000000  421.799988  421.799988
#
#     Volume
# 0  9867270
# 1  6291441
# 2  6191428

# %%
df1.shape
# Out:
# (1233, 7)

# %%
df1.set_index('Date', inplace=True)

# %%
df1.index = pd.to_datetime(df.index, format = '%Y/%m/%d')

# %%
df1
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-11-15  414.299988  417.549988  407.000000  408.649994  408.649994
# 2017-11-16  411.350006  415.899994  411.350006  413.450012  413.450012
# 2017-11-17  419.450012  423.450012  417.000000  421.799988  421.799988
# 2017-11-20  421.000000  425.700012  420.100006  423.000000  423.000000
# 2017-11-21  424.450012  430.000000  422.500000  424.250000  424.250000
# ...                ...         ...         ...         ...         ...
# 2022-11-04  418.200012  426.000000  416.899994  425.350006  425.350006
# 2022-11-07  428.250000  437.500000  428.250000  435.000000  435.000000
# 2022-11-09  439.200012  441.200012  432.000000  433.149994  433.149994
# 2022-11-10  420.500000  420.549988  409.200012  412.200012  412.200012
# 2022-11-11  420.000000  425.500000  414.700012  423.500000  423.500000
#
#               Volume
# Date
# 2017-11-15   9867270
# 2017-11-16   6291441
# 2017-11-17   6191428
# 2017-11-20   4051153
# 2017-11-21   6745407
# ...              ...
# 2022-11-04  12277023
# 2022-11-07  15058076
# 2022-11-09  14471443
# 2022-11-10  26251660
# 2022-11-11  19296401
#
# [1233 rows x 6 columns]

# %%
adf_test(df1['Close'])
# Out:
# ADF Statistics: -1.1490244440559358
# p- value: 0.6951311109960278
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
## Use Techniques Differencing --> 
# one dayy differencing to convery into stationary data
# we can;t work with seasonal data
df1['first_diff_Close']=df1['Close']-df1['Close'].shift(1)

# %%
df1.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-11-15  414.299988  417.549988  407.000000  408.649994  408.649994
# 2017-11-16  411.350006  415.899994  411.350006  413.450012  413.450012
# 2017-11-17  419.450012  423.450012  417.000000  421.799988  421.799988
# 2017-11-20  421.000000  425.700012  420.100006  423.000000  423.000000
# 2017-11-21  424.450012  430.000000  422.500000  424.250000  424.250000
#
#              Volume  first_diff_Close
# Date
# 2017-11-15  9867270               NaN
# 2017-11-16  6291441          4.800018
# 2017-11-17  6191428          8.349976
# 2017-11-20  4051153          1.200012
# 2017-11-21  6745407          1.250000

# %%
adf_test(df1['first_diff_Close'].dropna())
# Out:
# ADF Statistics: -9.125982827214441
# p- value: 3.112876744456458e-15
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
# now time to determine p(pacf) and q(acf) value
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %% [raw]
# Final Thoughts on Autocorrelation and Partial Autocorrelation
# Identification of an AR model is often best done with the PACF.
#
# For an AR model, the theoretical PACF “shuts off” past the order of the model. The phrase “shuts off” means that in theory the partial autocorrelations are equal to 0 beyond that point. Put another way, the number of non-zero partial autocorrelations gives the order of the AR model. By the “order of the model” we mean the most extreme lag of x that is used as a predictor.
# Identification of an MA model is often best done with the ACF rather than the PACF.
#
# For an MA model, the theoretical PACF does not shut off, but instead tapers toward 0 in some manner. A clearer pattern for an MA model is in the ACF. The ACF will have non-zero autocorrelations only at lags involved in the model.
#
# p,d,q
# p AR model lags
# d differencing
# q MA lags

# %%
acf = plot_acf(df1["Close"].dropna())

# %%
acf12 = plot_pacf(df1["Close"].dropna())
# Out:
# C:\Users\BIPLAB\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
df1.shape
# Out:
# (1233, 7)

# %%
### split train and test data
df1.head(3)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-11-15  414.299988  417.549988  407.000000  408.649994  408.649994
# 2017-11-16  411.350006  415.899994  411.350006  413.450012  413.450012
# 2017-11-17  419.450012  423.450012  417.000000  421.799988  421.799988
#
#              Volume  first_diff_Close
# Date
# 2017-11-15  9867270               NaN
# 2017-11-16  6291441          4.800018
# 2017-11-17  6191428          8.349976

# %%
df1.tail(3)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-11-09  439.200012  441.200012  432.000000  433.149994  433.149994
# 2022-11-10  420.500000  420.549988  409.200012  412.200012  412.200012
# 2022-11-11  420.000000  425.500000  414.700012  423.500000  423.500000
#
#               Volume  first_diff_Close
# Date
# 2022-11-09  14471443         -1.850006
# 2022-11-10  26251660        -20.949982
# 2022-11-11  19296401         11.299988

# %%
df1.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from datetime import datetime,timedelta
train_dataset_end=datetime(2021,12,1)
test_dataset_end=datetime(2022,11,11)

# %%
train_data=df1[:train_dataset_end]
test_data=df1[train_dataset_end+timedelta(days=1):test_dataset_end]

# %%
train_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-11-15  414.299988  417.549988  407.000000  408.649994  408.649994
# 2017-11-16  411.350006  415.899994  411.350006  413.450012  413.450012
# 2017-11-17  419.450012  423.450012  417.000000  421.799988  421.799988
# 2017-11-20  421.000000  425.700012  420.100006  423.000000  423.000000
# 2017-11-21  424.450012  430.000000  422.500000  424.250000  424.250000
# ...                ...         ...         ...         ...         ...
# 2021-11-25  490.799988  495.149994  486.500000  492.750000  492.750000
# 2021-11-26  486.000000  486.750000  458.000000  460.200012  460.200012
# 2021-11-29  457.000000  470.750000  443.100006  461.450012  461.450012
# 2021-11-30  466.549988  478.000000  455.649994  458.600006  458.600006
# 2021-12-01  467.850006  478.399994  463.549988  475.250000  475.250000
#
#               Volume  first_diff_Close
# Date
# 2017-11-15   9867270               NaN
# 2017-11-16   6291441          4.800018
# 2017-11-17   6191428          8.349976
# 2017-11-20   4051153          1.200012
# 2017-11-21   6745407          1.250000
# ...              ...               ...
# 2021-11-25  15336539          4.100006
# 2021-11-26  51787989        -32.549988
# 2021-11-29  42819150          1.250000
# 2021-11-30  35471800         -2.850006
# 2021-12-01  28256188         16.649994
#
# [998 rows x 7 columns]

# %%
train_data['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
test_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-12-02  479.399994  480.450012  471.700012  479.100006  479.100006
# 2021-12-03  480.000000  484.700012  477.299988  480.100006  480.100006
# 2021-12-06  480.100006  480.899994  466.000000  467.200012  467.200012
# 2021-12-07  476.850006  484.899994  471.000000  481.799988  481.799988
# 2021-12-08  484.500000  495.950012  483.500000  493.899994  493.899994
# ...                ...         ...         ...         ...         ...
# 2022-11-04  418.200012  426.000000  416.899994  425.350006  425.350006
# 2022-11-07  428.250000  437.500000  428.250000  435.000000  435.000000
# 2022-11-09  439.200012  441.200012  432.000000  433.149994  433.149994
# 2022-11-10  420.500000  420.549988  409.200012  412.200012  412.200012
# 2022-11-11  420.000000  425.500000  414.700012  423.500000  423.500000
#
#               Volume  first_diff_Close
# Date
# 2021-12-02  21012008          3.850006
# 2021-12-03  20948900          1.000000
# 2021-12-06  17473075        -12.899994
# 2021-12-07  21280797         14.599976
# 2021-12-08  20581817         12.100006
# ...              ...               ...
# 2022-11-04  12277023          9.100006
# 2022-11-07  15058076          9.649994
# 2022-11-09  14471443         -1.850006
# 2022-11-10  26251660        -20.949982
# 2022-11-11  19296401         11.299988
#
# [235 rows x 7 columns]

# %%
## create a ARIMA model
from statsmodels.tsa.arima.model import ARIMA

# %%
model_ARIMA_close=ARIMA(df1['Close'],order=(32,1,2))
# Out:
# C:\Users\BIPLAB\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\BIPLAB\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\BIPLAB\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
model_Arima_fit_close=model_ARIMA_close.fit()
# Out:
# C:\Users\BIPLAB\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model_Arima_fit_close.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1233
# Model:                ARIMA(32, 1, 2)   Log Likelihood               -4281.711
# Date:                Thu, 22 Dec 2022   AIC                           8633.422
# Time:                        10:33:18   BIC                           8812.496
# Sample:                             0   HQIC                          8700.790
#                                - 1233
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0
# 2021-12-06  17473075        -12.899994
# 2021-12-07  21280797         14.599976
# 2021-12-08  20581817         12.100006
# ...              ...               ...
# 2022-11-04  12277023          9.100006
# 2022-11-07  15058076          9.649994
# 2022-11-09  14471443         -1.850006
# 2022-11-10  26251660        -20.949982
# 2022-11-11  19296401         11.299988
#
# [235 rows x 7 columns]

# %%
##prediction
pred_start_date=test_data.index[0]
pred_end_date=test_data.index[-1]
print(pred_start_date)
print(pred_end_date)
# Out:
# 2021-12-02 00:00:00
# 2022-11-11 00:00:00

# %%
pred=model_Arima_fit_close.predict(start=pred_start_date,end=pred_end_date)
residuals=test_data['Close']-pred

# %%
pred
# Out:
# Date
# 2021-12-02    471.226038
# 2021-12-03    483.488463
# 2021-12-06    474.634296
# 2021-12-07    467.672847
# 2021-12-08    480.416781
#                  ...
# 2022-11-04    415.541861
# 2022-11-07    424.163992
# 2022-11-09    437.114420
# 2022-11-10    435.177713
# 2022-11-11    412.439027
# Name: predicted_mean, Length: 235, dtype: float64

# %%
residuals
# Out:
# Date
# 2021-12-02     7.873968
# 2021-12-03    -3.388457
# 2021-12-06    -7.434284
# 2021-12-07    14.127141
# 2021-12-08    13.483213
#                 ...
# 2022-11-04     9.808145
# 2022-11-07    10.836008
# 2022-11-09    -3.964426
# 2022-11-10   -22.977701
# 2022-11-11    11.060973
# Length: 235, dtype: float64

# %%
model_Arima_fit_close.resid.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
test_data['Predicted_ARIMA_close']=pred
# Out:
# C:\Users\BIPLAB\AppData\Local\Temp\ipykernel_5004\4048640912.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['Predicted_ARIMA_close']=pred

# %%
test_data[['Close','Predicted_ARIMA_close']].plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
pred
# Out:
# Date
# 2021-12-02    471.226038
# 2021-12-03    483.488463
# 2021-12-06    474.634296
# 2021-12-07    467.672847
# 2021-12-08    480.416781
#                  ...
# 2022-11-04    415.541861
# 2022-11-07    424.163992
# 2022-11-09    437.114420
# 2022-11-10    435.177713
# 2022-11-11    412.439027
# Name: predicted_mean, Length: 235, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
rmse= sqrt(mean_squared_error(pred,test_data['Close']))
rmse
# Out:
# 10.071733552493669

# %%
test_data['Close'].mean()
# as rmse is very lesser than mean then our model is a good model
# Out:
# 445.3608511404254

# %%
##prediction
pred_start_date=test_data.index[-1]
pred_end_date='2023-02-20 00:00:00'
print(pred_start_date)
print(pred_end_date)
# Out:
# 2022-11-11 00:00:00
# 2023-02-20 00:00:00

# %%
index_future_dates = pd.date_range(start='2022-12-14',end='2023-02-20')
pred1=model_Arima_fit_close.predict(start=len(df1),end=len(df1)+68)
pred1.index=index_future_dates
# residuals1=test_data['Close']-pred1
# Out:
# C:\Users\BIPLAB\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
pred1
# Out:
# 2022-12-14    424.100738
# 2022-12-15    426.655243
# 2022-12-16    424.895174
# 2022-12-17    426.852552
# 2022-12-18    425.944367
#                  ...
# 2023-02-16    425.969215
# 2023-02-17    426.000708
# 2023-02-18    425.957524
# 2023-02-19    426.014909
# 2023-02-20    425.976746
# Freq: D, Name: predicted_mean, Length: 69, dtype: float64

# %%
pred1.plot()
# Out:
# <AxesSubplot:>

# %%
print('r2_score', r2_score(test_data['Close'],pred))
# Out:
# r2_score 0.9154732143422681

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-24  416.000000  416.250000  402.649994  403.600006  403.600006
# 2018-01-25  403.450012  407.649994  398.000000  400.299988  400.299988
# 2018-01-29  402.500000  405.899994  398.100006  399.250000  399.250000
# 2018-01-30  400.000000  402.299988  395.000000  395.850006  395.850006
# 2018-01-31  395.500000  400.950012  395.250000  399.500000  399.500000
# ...                ...         ...         ...         ...         ...
# 2022-11-04  418.200012  426.000000  416.899994  425.350006  425.350006
# 2022-11-07  428.250000  437.500000  428.250000  435.000000  435.000000
# 2022-11-09  439.200012  441.200012  432.000000  433.149994  433.149994
# 2022-11-10  420.500000  420.549988  409.200012  412.200012  412.200012
# 2022-11-11  420.000000  425.500000  414.700012  423.500000  423.500000
#
#               Volume  Close:2 days rolling  Close:5 days rolling  \
# Date
# 2018-01-24  10789570            410.800003            416.100000
# 2018-01-25  16312167            401.949997            412.369995
# 2018-01-29   5789602            399.774994            408.609998
# 2018-01-30   6963005            397.550003            403.400000
# 2018-01-31   5111454            397.675003            399.700000
# ...              ...                   ...                   ...
# 2022-11-04  12277023            420.800003            419.570001
# 2022-11-07  15058076            430.175003            424.020001
# 2022-11-09  14471443            434.074997            426.379999
# 2022-11-10  26251660            422.675003            424.390002
# 2022-11-11  19296401            417.850006            425.840002
#
#             Close:7 days rolling  Close:10 days rolling  \
# Date
# 2018-01-24            417.907144             422.955002
# 2018-01-25            414.821429             419.510001
# 2018-01-29            411.435713             415.725000
# 2018-01-30            408.135712             412.075000
# 2018-01-31            405.485713             409.835001
# ...                          ...                    ...
# 2022-11-04            416.492859             411.964999
# 2022-11-07            420.392857             415.660001
# 2022-11-09            423.714286             418.814999
# 2022-11-10            423.635716             419.580002
# 2022-11-11            423.942858             421.160001
#
#             Close:30 days rolling  Close:50 days rolling     EMA_0.1  \
# Date
# 2018-01-24             423.033334             418.999000  422.411007
# 2018-01-25             422.978334             418.832000  420.199905
# 2018-01-29             422.873334             418.548000  418.104915
# 2018-01-30             422.565000             418.029000  415.879424
# 2018-01-31             422.355001             417.559000  414.241482
# ...                           ...                    ...         ...
# 2022-11-04             406.253334             424.079001  411.659894
# 2022-11-07             406.346666             423.515001  413.993905
# 2022-11-09             406.681666             422.994000  415.909513
# 2022-11-10             407.171666             421.937001  415.538563
# 2022-11-11             407.995000             421.340001  416.334707
#
#                EMA_0.3
# Date
# 2018-01-24  416.033071
# 2018-01-25  411.313146
# 2018-01-29  407.694202
# 2018-01-30  404.140943
# 2018-01-31  402.748660
# ...                ...
# 2022-11-04  418.252103
# 2022-11-07  423.276472
# 2022-11-09  426.238529
# 2022-11-10  422.026974
# 2022-11-11  422.468882
#
# [1184 rows x 14 columns]

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
rmse_2days= sqrt(mean_squared_error(df['Close:2 days rolling'],df['Close']))
rmse_2days
# Out:
# 4.032042982911794

# %%
rmse_5days= sqrt(mean_squared_error(df['Close:5 days rolling'],df['Close']))
rmse_5days
# Out:
# 8.786469804013482

# %%
rmse_7days= sqrt(mean_squared_error(df['Close:5 days rolling'],df['Close']))
rmse_7days
# Out:
# 8.786469804013482

# %%
rmse_10days= sqrt(mean_squared_error(df['Close:10 days rolling'],df['Close']))
rmse_10days
# Out:
# 13.830674657651535

# %%
rmse_30days= sqrt(mean_squared_error(df['Close:30 days rolling'],df['Close']))
rmse_30days
# Out:
# 27.71735351525462

# %%
rmse_50days= sqrt(mean_squared_error(df['Close:50 days rolling'],df['Close']))
rmse_50days
# Out:
# 37.06883556049632

# %%
rmse_EMA01 = sqrt(mean_squared_error(df['EMA_0.1'],df['Close']))
rmse_EMA01
# Out:
# 18.01914507133906

# %%
rmse_EMA_03= sqrt(mean_squared_error(df['EMA_0.3'],df['Close']))
rmse_EMA_03
# Out:
# 7.995720223136872

# %%
df2=pd.read_csv('TATAMOTORS_data.csv')

# %%
df2.set_index('Date', inplace=True)

# %%
df2.index = pd.to_datetime(df2.index, format = '%Y/%m/%d')

# %%
x = df2.iloc[:, :-1]
y = df2.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_test = lr.predict(x_test)

# %%
lr.coef_
# Out:
# array([-2102083.18650645,  5026508.38844424, -2498111.9160121 ,
#         -300876.63806371,  -300876.63806371])

# %%
lr.intercept_
# Out:
# 50622179.0415038

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
print('MAE', mean_absolute_error(y_test,y_pred_test))
print('MSE', mean_squared_error(y_test,y_pred_test))
print('RMSE', np.sqrt(mean_squared_error(y_test,y_pred_test)))
print('r2_score', r2_score(y_test,y_pred_test))
# Out:
# MAE 17270739.756470304
# MSE 758691994025734.9
# RMSE 27544364.106396336
# r2_score 0.41723287307243306

# %%
r2=r2_score(y_test,y_pred_test)

# %%
r2
# Out:
# 0.41723287307243306

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(x_train, y_train)
# Out:
# SVR()

# %%
y_pred_test_svm = regressor.predict(x_test)

# %%
print('MAE', mean_absolute_error(y_test,y_pred_test_svm))
print('MSE', mean_squared_error(y_test,y_pred_test_svm))
print('RMSE', np.sqrt(mean_squared_error(y_test,y_pred_test_svm)))
print('r2_score', r2_score(y_test,y_pred_test_svm))
# Out:
# MAE 21648593.202751305
# MSE 1431813705138668.0
# RMSE 37839314.27944576
# r2_score -0.09980593680928274

# %%
from sklearn.ensemble import RandomForestRegressor
regressor_rf = RandomForestRegressor(n_estimators = 80, random_state = 0)
regressor_rf.fit(x, y)
# Out:
# RandomForestRegressor(n_estimators=80, random_state=0)

# %%
y_pred_test_rf = regressor_rf.predict(x_test)

# %%
print('MAE', mean_absolute_error(y_test,y_pred_test_rf))
print('MSE', mean_squared_error(y_test,y_pred_test_rf))
print('RMSE', np.sqrt(mean_squared_error(y_test,y_pred_test_rf)))
print('r2_score', r2_score(y_test,y_pred_test_rf))
# Out:
# MAE 6172451.682742915
# MSE 107032629169188.44
# RMSE 10345657.502990732
# r2_score 0.9177860076558079

# %%
index_future_dates_rf = pd.date_range(start='2022-12-14',end='2023-02-20')
pred_rf=regressor_rf.predict(start=len(df1),end=len(df1)+68)
pred1_rf.index=index_future_dates
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5004\521320773.py in <module>
#       1 index_future_dates_rf = pd.date_range(start='2022-12-14',end='2023-02-20')
# ----> 2 pred_rf=regressor_rf.predict(start=len(df1),end=len(df1)+68)
#       3 pred1_rf.index=index_future_dates
#
# TypeError: predict() got an unexpected keyword argument 'start'
