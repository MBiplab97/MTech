# %% [markdown]
# !pip install pandas-datareader

# %% [markdown]
# !pip install pmdarima

# %%
import pandas_datareader as pdr
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sms
from datetime import datetime

# %%
df=pdr.get_data_yahoo('TATAMOTORS.NS')
df.head(3)
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2017-12-15  409.000000  404.200012  406.500000  405.100006  5614113
# 2017-12-18  409.899994  389.299988  399.000000  405.799988  5356208
# 2017-12-19  421.700012  407.350006  407.350006  420.100006  9686883
#
#              Adj Close
# Date
# 2017-12-15  405.100006
# 2017-12-18  405.799988
# 2017-12-19  420.100006

# %%
df.tail(3)
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2022-12-12  416.899994  408.000000  412.000000  414.149994  8009229
# 2022-12-13  421.500000  417.250000  419.950012  418.500000  9717894
# 2022-12-14  421.350006  417.350006  420.549988  417.899994  6312970
#
#              Adj Close
# Date
# 2022-12-12  414.149994
# 2022-12-13  418.500000
# 2022-12-14  417.899994

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1234 entries, 2017-12-15 to 2022-12-14
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       1234 non-null   float64
#  1   Low        1234 non-null   float64
#  2   Open       1234 non-null   float64
#  3   Close      1234 non-null   float64
#  4   Volume     1234 non-null   int64
#  5   Adj Close  1234 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 67.5 KB

# %%
df.shape
# Out:
# (1234, 6)

# %%
df.plot(figsize=(10,3))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['High'].plot(figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Close'].plot(figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df[['High','Close']].plot(figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
## xlimit and y limit
df['Close'].plot(xlim=['2017-06-27','2020-09-23'],figsize=(12,4))
# df['High'].plot(xlim=['2017-06-27','2020-09-23'])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Close'].plot(xlim=['2020-01-01','2022-09-01'],ylim=[0,1000],figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.index
# Out:
# DatetimeIndex(['2017-12-15', '2017-12-18', '2017-12-19', '2017-12-20',
#                '2017-12-21', '2017-12-22', '2017-12-26', '2017-12-27',
#                '2017-12-28', '2017-12-29',
#                ...
#                '2022-12-01', '2022-12-02', '2022-12-05', '2022-12-06',
#                '2022-12-07', '2022-12-08', '2022-12-09', '2022-12-12',
#                '2022-12-13', '2022-12-14'],
#               dtype='datetime64[ns]', name='Date', length=1234, freq=None)

# %% [markdown]
# # Time Resampling

# %%
df.resample(rule='A').min() 
#It gives us MIN values of all parameters in each year.
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2017-12-31  409.000000  389.299988  399.000000  405.100006   3673355
# 2018-12-31  159.500000  154.649994  155.000000  157.100006   3820313
# 2019-12-31  111.599998  106.000000  108.900002  107.699997   6141180
# 2020-12-31   66.900002   63.500000   66.500000   65.300003  11749453
# 2021-12-31  187.000000  184.500000  184.949997  186.500000   5531940
# 2022-12-31  384.649994  366.200012  382.000000  372.299988   2871205
#
#              Adj Close
# Date
# 2017-12-31  405.100006
# 2018-12-31  157.100006
# 2019-12-31  107.699997
# 2020-12-31   65.300003
# 2021-12-31  186.500000
# 2022-12-31  372.299988

# %%
df.resample(rule='A').max()  
#It gives us MAX values of all parameters in each year.
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2017-12-31  433.450012  421.149994  424.000000  431.850006   11191127
# 2018-12-31  443.500000  433.000000  440.399994  439.299988  142760251
# 2019-12-31  239.350006  231.699997  235.000000  236.250000  184435614
# 2020-12-31  201.699997  196.899994  199.500000  200.350006  215476711
# 2021-12-31  536.700012  520.250000  531.450012  530.150024  390577839
# 2022-12-31  528.500000  512.000000  527.900024  525.000000   71425747
#
#              Adj Close
# Date
# 2017-12-31  431.850006
# 2018-12-31  439.299988
# 2019-12-31  236.250000
# 2020-12-31  200.350006
# 2021-12-31  530.150024
# 2022-12-31  525.000000

# %%
##rule = A : year end frequency
df.resample(rule='A').max()[['Open','Close']].plot(figsize=(15,8))
# PLOT open max price over the year
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.resample(rule='QS').max()
##RULE QS : quaterly start frequency--> after three months
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2017-10-01  433.450012  421.149994  424.000000  431.850006   11191127
# 2018-01-01  443.500000  433.000000  440.399994  439.299988   25294860
# 2018-04-01  372.350006  359.799988  362.600006  364.100006   46104103
# 2018-07-01  282.000000  272.899994  277.250000  277.399994   53282545
# 2018-10-01  232.800003  225.800003  230.000000  229.350006  142760251
# 2019-01-01  198.350006  187.800003  195.399994  194.050003  102256857
# 2019-04-01  239.350006  231.699997  235.000000  236.250000  100834335
# 2019-07-01  172.350006  166.300003  170.000000  170.000000   96568372
# 2019-10-01  187.899994  181.550003  184.000000  185.149994  184435614
# 2020-01-01  201.699997  196.899994  199.500000  200.350006  143550830
# 2020-04-01  119.150002  113.349998  117.449997  115.449997  215476711
# 2020-07-01  155.199997  149.550003  151.600006  151.850006  197510376
# 2020-10-01  188.800003  183.250000  187.899994  186.350006  171801183
# 2021-01-01  357.000000  346.500000  348.649994  348.500000  390577839
# 2021-04-01  360.750000  351.500000  356.200012  355.950012  119407026
# 2021-07-01  358.200012  344.000000  348.000000  346.100006  164083830
# 2021-10-01  536.700012  520.250000  531.450012  530.150024  197949387
# 2022-01-01  528.500000  512.000000  527.900024  525.000000   59776817
# 2022-04-01  462.700012  452.600006  457.000000  458.049988   71425747
# 2022-07-01  494.399994  484.200012  490.899994  489.850006   43084536
# 2022-10-01  443.600006  436.850006  443.000000  439.399994   32914630
#
#              Adj Close
# Date
# 2017-10-01  431.850006
# 2018-01-01  439.299988
# 2018-04-01  364.100006
# 2018-07-01  277.399994
# 2018-10-01  229.350006
# 2019-01-01  194.050003
# 2019-04-01  236.250000
# 2019-07-01  170.000000
# 2019-10-01  185.149994
# 2020-01-01  200.350006
# 2020-04-01  115.449997
# 2020-07-01  151.850006
# 2020-10-01  186.350006
# 2021-01-01  348.500000
# 2021-04-01  355.950012
# 2021-07-01  346.100006
# 2021-10-01  530.150024
# 2022-01-01  525.000000
# 2022-04-01  458.049988
# 2022-07-01  489.850006
# 2022-10-01  439.399994

# %%
##RULE QS : quaterly start frequency--> after three months 
##https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78
df.resample(rule='QS').max()[['High','Close']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
##RULE BA : Business End Frequency
##https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78
df.resample(rule='BA').max()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2017-12-29  433.450012  421.149994  424.000000  431.850006   11191127
# 2018-12-31  443.500000  433.000000  440.399994  439.299988  142760251
# 2019-12-31  239.350006  231.699997  235.000000  236.250000  184435614
# 2020-12-31  201.699997  196.899994  199.500000  200.350006  215476711
# 2021-12-31  536.700012  520.250000  531.450012  530.150024  390577839
# 2022-12-30  528.500000  512.000000  527.900024  525.000000   71425747
#
#              Adj Close
# Date
# 2017-12-29  431.850006
# 2018-12-31  439.299988
# 2019-12-31  236.250000
# 2020-12-31  200.350006
# 2021-12-31  530.150024
# 2022-12-30  525.000000

# %%
df.resample(rule='BQS').max()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2017-10-02  433.450012  421.149994  424.000000  431.850006   11191127
# 2018-01-01  443.500000  433.000000  440.399994  439.299988   25294860
# 2018-04-02  372.350006  359.799988  362.600006  364.100006   46104103
# 2018-07-02  282.000000  272.899994  277.250000  277.399994   53282545
# 2018-10-01  232.800003  225.800003  230.000000  229.350006  142760251
# 2019-01-01  198.350006  187.800003  195.399994  194.050003  102256857
# 2019-04-01  239.350006  231.699997  235.000000  236.250000  100834335
# 2019-07-01  172.350006  166.300003  170.000000  170.000000   96568372
# 2019-10-01  187.899994  181.550003  184.000000  185.149994  184435614
# 2020-01-01  201.699997  196.899994  199.500000  200.350006  143550830
# 2020-04-01  119.150002  113.349998  117.449997  115.449997  215476711
# 2020-07-01  155.199997  149.550003  151.600006  151.850006  197510376
# 2020-10-01  188.800003  183.250000  187.899994  186.350006  171801183
# 2021-01-01  357.000000  346.500000  348.649994  348.500000  390577839
# 2021-04-01  360.750000  351.500000  356.200012  355.950012  119407026
# 2021-07-01  358.200012  344.000000  348.000000  346.100006  164083830
# 2021-10-01  536.700012  520.250000  531.450012  530.150024  197949387
# 2022-01-03  528.500000  512.000000  527.900024  525.000000   59776817
# 2022-04-01  462.700012  452.600006  457.000000  458.049988   71425747
# 2022-07-01  494.399994  484.200012  490.899994  489.850006   43084536
# 2022-10-03  443.600006  436.850006  443.000000  439.399994   32914630
#
#              Adj Close
# Date
# 2017-10-02  431.850006
# 2018-01-01  439.299988
# 2018-04-02  364.100006
# 2018-07-02  277.399994
# 2018-10-01  229.350006
# 2019-01-01  194.050003
# 2019-04-01  236.250000
# 2019-07-01  170.000000
# 2019-10-01  185.149994
# 2020-01-01  200.350006
# 2020-04-01  115.449997
# 2020-07-01  151.850006
# 2020-10-01  186.350006
# 2021-01-01  348.500000
# 2021-04-01  355.950012
# 2021-07-01  346.100006
# 2021-10-01  530.150024
# 2022-01-03  525.000000
# 2022-04-01  458.049988
# 2022-07-01  489.850006
# 2022-10-03  439.399994

# %%
##plotting
df['Close'].resample(rule='A').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# RULE M : monthly data
df['Open'].resample(rule='M').max().plot(kind='bar',figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['High'].rolling(11).mean().head(20)
# Out:
# Date
# 2017-12-15           NaN
# 2017-12-18           NaN
# 2017-12-19           NaN
# 2017-12-20           NaN
# 2017-12-21           NaN
# 2017-12-22           NaN
# 2017-12-26           NaN
# 2017-12-27           NaN
# 2017-12-28           NaN
# 2017-12-29           NaN
# 2018-01-01    424.359092
# 2018-01-02    427.254547
# 2018-01-03    430.118183
# 2018-01-04    431.172727
# 2018-01-05    431.954545
# 2018-01-08    432.877275
# 2018-01-09    434.431821
# 2018-01-10    435.718184
# 2018-01-11    436.550002
# 2018-01-12    438.163638
# Name: High, dtype: float64

# %%
df['High'].rolling(11).max().head(20)
# Out:
# Date
# 2017-12-15           NaN
# 2017-12-18           NaN
# 2017-12-19           NaN
# 2017-12-20           NaN
# 2017-12-21           NaN
# 2017-12-22           NaN
# 2017-12-26           NaN
# 2017-12-27           NaN
# 2017-12-28           NaN
# 2017-12-29           NaN
# 2018-01-01    436.399994
# 2018-01-02    440.850006
# 2018-01-03    441.399994
# 2018-01-04    441.399994
# 2018-01-05    441.399994
# 2018-01-08    441.399994
# 2018-01-09    443.500000
# 2018-01-10    443.500000
# 2018-01-11    443.500000
# 2018-01-12    443.500000
# Name: High, dtype: float64

# %%
df.head()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2017-12-15  409.000000  404.200012  406.500000  405.100006   5614113
# 2017-12-18  409.899994  389.299988  399.000000  405.799988   5356208
# 2017-12-19  421.700012  407.350006  407.350006  420.100006   9686883
# 2017-12-20  427.750000  419.250000  421.950012  422.600006  11191127
# 2017-12-21  426.049988  419.549988  424.000000  420.799988   4885225
#
#              Adj Close
# Date
# 2017-12-15  405.100006
# 2017-12-18  405.799988
# 2017-12-19  420.100006
# 2017-12-20  422.600006
# 2017-12-21  420.799988

# %%
# simple moving average
df['Open:30 days rolling']=df['Open'].rolling(30).mean()

# %%
df.head(31)
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2017-12-15  409.000000  404.200012  406.500000  405.100006   5614113
# 2017-12-18  409.899994  389.299988  399.000000  405.799988   5356208
# 2017-12-19  421.700012  407.350006  407.350006  420.100006   9686883
# 2017-12-20  427.750000  419.250000  421.950012  422.600006  11191127
# 2017-12-21  426.049988  419.549988  424.000000  420.799988   4885225
# 2017-12-22  426.399994  420.899994  422.049988  422.000000   5345261
# 2017-12-26  425.149994  421.149994  422.000000  424.200012   3700655
# 2017-12-27  428.450012  420.299988  423.500000  422.450012   3673355
# 2017-12-28  423.700012  416.000000  423.500000  418.600006   5018893
# 2017-12-29  433.450012  417.149994  418.000000  431.850006   8640908
# 2018-01-01  436.399994  422.250000  430.950012  424.450012   6807536
# 2018-01-02  440.850006  422.000000  428.850006  439.299988  15331261
# 2018-01-03  441.399994  431.950012  440.399994  433.899994   9794953
# 2018-01-04  433.299988  425.750000  430.000000  429.950012   8395377
# 2018-01-05  436.350006  429.799988  431.250000  431.600006   7021611
# 2018-01-08  436.200012  431.649994  432.000000  433.549988   4635214
# 2018-01-09  443.500000  433.000000  434.250000  437.549988  12629045
# 2018-01-10  439.299988  431.299988  438.000000  433.299988   4702579
# 2018-01-11  437.600006  432.899994  433.500000  434.750000   4564895
# 2018-01-12  441.450012  432.100006  437.000000  437.100006   7408870
# 2018-01-15  440.049988  431.049988  438.049988  432.350006   4042775
# 2018-01-16  435.200012  419.500000  433.000000  421.899994   5623745
# 2018-01-17  424.500000  410.100006  422.049988  422.950012  10204447
# 2018-01-18  428.299988  414.450012  424.000000  418.950012   9579830
# 2018-01-19  421.950012  415.049988  415.200012  418.049988   3894062
# 2018-01-22  424.399994  418.450012  419.049988  421.899994   4643782
# 2018-01-23  422.799988  414.750000  422.799988  418.000000   6185011
# 2018-01-24  416.250000  402.649994  416.000000  403.600006  10789570
# 2018-01-25  407.649994  398.000000  403.450012  400.299988  16312167
# 2018-01-29  405.899994  398.100006  402.500000  399.250000   5789602
# 2018-01-30  402.299988  395.000000  400.000000  395.850006   6963005
#
#              Adj Close  Open:30 days rolling
# Date
# 2017-12-15  405.100006                   NaN
# 2017-12-18  405.799988                   NaN
# 2017-12-19  420.100006                   NaN
# 2017-12-20  422.600006                   NaN
# 2017-12-21  420.799988                   NaN
# 2017-12-22  422.000000                   NaN
# 2017-12-26  424.200012                   NaN
# 2017-12-27  422.450012                   NaN
# 2017-12-28  418.600006                   NaN
# 2017-12-29  431.850006                   NaN
# 2018-01-01  424.450012                   NaN
# 2018-01-02  439.299988                   NaN
# 2018-01-03  433.899994                   NaN
# 2018-01-04  429.950012                   NaN
# 2018-01-05  431.600006                   NaN
# 2018-01-08  433.549988                   NaN
# 2018-01-09  437.549988                   NaN
# 2018-01-10  433.299988                   NaN
# 2018-01-11  434.750000                   NaN
# 2018-01-12  437.100006                   NaN
# 2018-01-15  432.350006                   NaN
# 2018-01-16  421.899994                   NaN
# 2018-01-17  422.950012                   NaN
# 2018-01-18  418.950012                   NaN
# 2018-01-19  418.049988                   NaN
# 2018-01-22  421.899994                   NaN
# 2018-01-23  418.000000                   NaN
# 2018-01-24  403.600006                   NaN
# 2018-01-25  400.299988                   NaN
# 2018-01-29  399.250000            423.338333
# 2018-01-30  395.850006            423.121666

# %%
df[['Open','Open:30 days rolling']].plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# here we specify xlim 
df[['Open','Open:30 days rolling']].plot(xlim=['2020-01-01','2022-01-01'],figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Open:10 days rolling']=df['Open'].rolling(10).mean()
df['Open:30 days rolling']=df['Open'].rolling(30).mean()
df['Open:50 days rolling']=df['Open'].rolling(50).mean()

# %%
df[['Open','Open:10 days rolling','Open:30 days rolling','Open:50 days rolling']].plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [raw]
# Smoothing curve tells us when to buy and when to sell stock

# %%
# cumulative moving average(here I use for only open stock)
# use expanding
df['Open'].expanding().mean().plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#  exponential moving average
df['EMA_0.1'] = df['Open'].ewm(alpha=0.1, adjust=False).mean()

# %%
df[['Open','EMA_0.1']].plot(xlim=['2020-01-01','2022-01-01'],figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['EMA_0.3'] = df['Open'].ewm(alpha=0.3, adjust=False).mean()

# %%
df[['Open','EMA_0.1','EMA_0.3']].plot(xlim=['2020-01-01','2022-01-01'],figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# exponential weightage moving average -- more smoothen curve
df['EWMA_5days'] = df['Open'].ewm(span=5).mean()

# %%
df[['Open','EMA_0.1','EWMA_5days']].plot(xlim=['2020-01-01','2022-01-01'],figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['EMA_0.33333'] = df['Open'].ewm(alpha=0.33333, adjust=False).mean()

# %%
df[['Open','EMA_0.33333','EWMA_5days']].plot(xlim=['2020-01-01','2022-01-01'],figsize=(12,5))
# both alpha =0.3 and span =5 is same almost
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [raw]
# # span = 2/(n+1)
# # n=5 means , span = 0.3333 , which is equivalent to alpha =0.3

# %%
df
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2017-12-15  409.000000  404.200012  406.500000  405.100006   5614113
# 2017-12-18  409.899994  389.299988  399.000000  405.799988   5356208
# 2017-12-19  421.700012  407.350006  407.350006  420.100006   9686883
# 2017-12-20  427.750000  419.250000  421.950012  422.600006  11191127
# 2017-12-21  426.049988  419.549988  424.000000  420.799988   4885225
# ...                ...         ...         ...         ...       ...
# 2022-12-08  421.399994  415.350006  421.000000  417.200012   9539923
# 2022-12-09  420.950012  409.549988  419.299988  413.299988   9920219
# 2022-12-12  416.899994  408.000000  412.000000  414.149994   8009229
# 2022-12-13  421.500000  417.250000  419.950012  418.500000   9717894
# 2022-12-14  421.350006  417.350006  420.549988  417.899994   6312970
#
#              Adj Close  Open:30 days rolling  Open:10 days rolling  \
# Date
# 2017-12-15  405.100006                   NaN                   NaN
# 2017-12-18  405.799988                   NaN                   NaN
# 2017-12-19  420.100006                   NaN                   NaN
# 2017-12-20  422.600006                   NaN                   NaN
# 2017-12-21  420.799988                   NaN                   NaN
# ...                ...                   ...                   ...
# 2022-12-08  417.200012            425.900000            432.279999
# 2022-12-09  413.299988            426.258333            431.709998
# 2022-12-12  414.149994            426.391667            429.409998
# 2022-12-13  418.500000            426.578334            428.154999
# 2022-12-14  417.899994            426.766667            426.709998
#
#             Open:50 days rolling     EMA_0.1     EMA_0.3  EWMA_5days  \
# Date
# 2017-12-15                   NaN  406.500000  406.500000  406.500000
# 2017-12-18                   NaN  405.750000  404.250000  402.000000
# 2017-12-19                   NaN  405.910001  405.180002  404.534213
# 2017-12-20                   NaN  407.514002  410.211005  411.768468
# 2017-12-21                   NaN  409.162602  414.347703  416.463985
# ...                          ...         ...         ...         ...
# 2022-12-08            416.467000  428.356134  428.697748  428.214211
# 2022-12-09            416.774999  427.450520  425.878420  425.242804
# 2022-12-12            417.117000  425.905468  421.714894  420.828536
# 2022-12-13            417.296000  425.309922  421.185429  420.535695
# 2022-12-14            417.747000  424.833929  420.994797  420.540459
#
#             EMA_0.33333
# Date
# 2017-12-15   406.500000
# 2017-12-18   404.000025
# 2017-12-19   405.116674
# 2017-12-20   410.727731
# 2017-12-21   415.151776
# ...                 ...
# 2022-12-08   428.214261
# 2022-12-09   425.242866
# 2022-12-12   420.828622
# 2022-12-13   420.535755
# 2022-12-14   420.540499
#
# [1234 rows x 13 columns]

# %% [markdown]
# # STAT MODEL WITH ARIMA

# %%
# since it is seasonal data we are going to use dickey fuller test
from statsmodels.tsa.stattools import adfuller

# %%
# H0 : It is not stationary
# H1 : It is stationary

# %%
def adf_test(series):
    result=adfuller(series)
    print('ADF Statistics: {}'.format(result[0]))
    print('p- value: {}'.format(result[1]))
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %% [markdown]
# #strong evidence against the null hypothesis, reject the null hypothesis.
# #Data has no unit root and is stationary
#
# #weak evidence against null hypothesis, time series has a unit root,
# #indicating it is non-stationary

# %%
df1=pdr.get_data_yahoo('TATAMOTORS.NS')
df1.head(3)
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2017-12-15  409.000000  404.200012  406.500000  405.100006  5614113
# 2017-12-18  409.899994  389.299988  399.000000  405.799988  5356208
# 2017-12-19  421.700012  407.350006  407.350006  420.100006  9686883
#
#              Adj Close
# Date
# 2017-12-15  405.100006
# 2017-12-18  405.799988
# 2017-12-19  420.100006

# %%
adf_test(df1['Close'])
# Out:
# ADF Statistics: -1.2871401600551604
# p- value: 0.6350349778741335
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
## Use Techniques Differencing --> 
# one dayy differencing to convery into stationary data
# we can;t work with seasonal data
df1['first_diff_Close']=df1['Close']-df1['Close'].shift(1)

# %%
df1.head()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2017-12-15  409.000000  404.200012  406.500000  405.100006   5614113
# 2017-12-18  409.899994  389.299988  399.000000  405.799988   5356208
# 2017-12-19  421.700012  407.350006  407.350006  420.100006   9686883
# 2017-12-20  427.750000  419.250000  421.950012  422.600006  11191127
# 2017-12-21  426.049988  419.549988  424.000000  420.799988   4885225
#
#              Adj Close  first_diff_Close
# Date
# 2017-12-15  405.100006               NaN
# 2017-12-18  405.799988          0.699982
# 2017-12-19  420.100006         14.300018
# 2017-12-20  422.600006          2.500000
# 2017-12-21  420.799988         -1.800018

# %%
adf_test(df1['first_diff_Close'].dropna())
# Out:
# ADF Statistics: -9.069423920536169
# p- value: 4.342678135628661e-15
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
# now time to determine p(pacf) and q(acf) value
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %% [raw]
# Final Thoughts on Autocorrelation and Partial Autocorrelation
# Identification of an AR model is often best done with the PACF.
#
# For an AR model, the theoretical PACF “shuts off” past the order of the model. The phrase “shuts off” means that in theory the partial autocorrelations are equal to 0 beyond that point. Put another way, the number of non-zero partial autocorrelations gives the order of the AR model. By the “order of the model” we mean the most extreme lag of x that is used as a predictor.
# Identification of an MA model is often best done with the ACF rather than the PACF.
#
# For an MA model, the theoretical PACF does not shut off, but instead tapers toward 0 in some manner. A clearer pattern for an MA model is in the ACF. The ACF will have non-zero autocorrelations only at lags involved in the model.
#
# p,d,q
# p AR model lags
# d differencing
# q MA lags

# %%
acf = plot_acf(df1["first_diff_Close"].dropna())
# q = 1 ---> assume by lookig at picture

# %%
acf12 = plot_pacf(df1["first_diff_Close"].dropna())
# p = 1
# d = seasonal different , here d =1
# Out:
# C:\Users\BIPLAB\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
df1.shape
# Out:
# (1234, 7)

# %%
### split train and test data
df1.head(3)
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2017-12-15  409.000000  404.200012  406.500000  405.100006  5614113
# 2017-12-18  409.899994  389.299988  399.000000  405.799988  5356208
# 2017-12-19  421.700012  407.350006  407.350006  420.100006  9686883
#
#              Adj Close  first_diff_Close
# Date
# 2017-12-15  405.100006               NaN
# 2017-12-18  405.799988          0.699982
# 2017-12-19  420.100006         14.300018

# %%
df1.tail(3)
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2022-12-12  416.899994  408.000000  412.000000  414.149994  8009229
# 2022-12-13  421.500000  417.250000  419.950012  418.500000  9717894
# 2022-12-14  421.350006  417.350006  420.549988  417.899994  6312970
#
#              Adj Close  first_diff_Close
# Date
# 2022-12-12  414.149994          0.850006
# 2022-12-13  418.500000          4.350006
# 2022-12-14  417.899994         -0.600006

# %%
df1.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from datetime import datetime,timedelta
train_dataset_end=datetime(2021,12,1)
test_dataset_end=datetime(2022,12,14)

# %%
train_data=df1[:train_dataset_end]
test_data=df1[train_dataset_end+timedelta(days=1):test_dataset_end]

# %%
train_data
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2017-12-15  409.000000  404.200012  406.500000  405.100006   5614113
# 2017-12-18  409.899994  389.299988  399.000000  405.799988   5356208
# 2017-12-19  421.700012  407.350006  407.350006  420.100006   9686883
# 2017-12-20  427.750000  419.250000  421.950012  422.600006  11191127
# 2017-12-21  426.049988  419.549988  424.000000  420.799988   4885225
# ...                ...         ...         ...         ...       ...
# 2021-11-25  495.149994  486.500000  490.799988  492.750000  15336539
# 2021-11-26  486.750000  458.000000  486.000000  460.200012  51787989
# 2021-11-29  470.750000  443.100006  457.000000  461.450012  42819150
# 2021-11-30  478.000000  455.649994  466.549988  458.600006  35471800
# 2021-12-01  478.399994  463.549988  467.850006  475.250000  28256188
#
#              Adj Close  first_diff_Close
# Date
# 2017-12-15  405.100006               NaN
# 2017-12-18  405.799988          0.699982
# 2017-12-19  420.100006         14.300018
# 2017-12-20  422.600006          2.500000
# 2017-12-21  420.799988         -1.800018
# ...                ...               ...
# 2021-11-25  492.750000          4.100006
# 2021-11-26  460.200012        -32.549988
# 2021-11-29  461.450012          1.250000
# 2021-11-30  458.600006         -2.850006
# 2021-12-01  475.250000         16.649994
#
# [976 rows x 7 columns]

# %%
train_data['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
test_data
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2021-12-02  480.450012  471.700012  479.399994  479.100006  21012008
# 2021-12-03  484.700012  477.299988  480.000000  480.100006  20948900
# 2021-12-06  480.899994  466.000000  480.100006  467.200012  17473075
# 2021-12-07  484.899994  471.000000  476.850006  481.799988  21280797
# 2021-12-08  495.950012  483.500000  484.500000  493.899994  20581817
# ...                ...         ...         ...         ...       ...
# 2022-12-08  421.399994  415.350006  421.000000  417.200012   9539923
# 2022-12-09  420.950012  409.549988  419.299988  413.299988   9920219
# 2022-12-12  416.899994  408.000000  412.000000  414.149994   8009229
# 2022-12-13  421.500000  417.250000  419.950012  418.500000   9717894
# 2022-12-14  421.350006  417.350006  420.549988  417.899994   6312970
#
#              Adj Close  first_diff_Close
# Date
# 2021-12-02  479.100006          3.850006
# 2021-12-03  480.100006          1.000000
# 2021-12-06  467.200012        -12.899994
# 2021-12-07  481.799988         14.599976
# 2021-12-08  493.899994         12.100006
# ...                ...               ...
# 2022-12-08  417.200012         -2.899994
# 2022-12-09  413.299988         -3.900024
# 2022-12-12  414.149994          0.850006
# 2022-12-13  418.500000          4.350006
# 2022-12-14  417.899994         -0.600006
#
# [258 rows x 7 columns]

# %%
## create a ARIMA model
from statsmodels.tsa.arima.model import ARIMA

# %%
model_ARIMA=ARIMA(df1['Close'],order=(1,1,1))
# Out:
# C:\Users\BIPLAB\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\BIPLAB\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\BIPLAB\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
model_Arima_fit=model_ARIMA.fit()
# Out:
# C:\Users\BIPLAB\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\BIPLAB\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'

# %%
model_Arima_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1234
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -4305.665
# Date:                Wed, 14 Dec 2022   AIC                           8617.330
# Time:                        17:18:33   BIC                           8632.682
# Sample:                             0   HQIC                          8623.105
#                                - 1234
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8737      0.071    -12.354      0.000      -1.012      -0.735
# ma.L1          0.8324      0.083     10.008      0.000       0.669       0.995
# sigma2        63.1925      1.004     62.933      0.000      61.224      65.161
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.06   Jarque-Bera (JB):             10032.53
# Prob(Q):                              0.30   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.10   Skew:                             0.95
# Prob(H) (two-sided):                  0.00   Kurtosis:                        16.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
test_data
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2021-12-02  480.450012  471.700012  479.399994  479.100006  21012008
# 2021-12-03  484.700012  477.299988  480.000000  480.100006  20948900
# 2021-12-06  480.899994  466.000000  480.100006  467.200012  17473075
# 2021-12-07  484.899994  471.000000  476.850006  481.799988  21280797
# 2021-12-08  495.950012  483.500000  484.500000  493.899994  20581817
# ...                ...         ...         ...         ...       ...
# 2022-12-08  421.399994  415.350006  421.000000  417.200012   9539923
# 2022-12-09  420.950012  409.549988  419.299988  413.299988   9920219
# 2022-12-12  416.899994  408.000000  412.000000  414.149994   8009229
# 2022-12-13  421.500000  417.250000  419.950012  418.500000   9717894
# 2022-12-14  421.350006  417.350006  420.549988  417.899994   6312970
#
#              Adj Close  first_diff_Close
# Date
# 2021-12-02  479.100006          3.850006
# 2021-12-03  480.100006          1.000000
# 2021-12-06  467.200012        -12.899994
# 2021-12-07  481.799988         14.599976
# 2021-12-08  493.899994         12.100006
# ...                ...               ...
# 2022-12-08  417.200012         -2.899994
# 2022-12-09  413.299988         -3.900024
# 2022-12-12  414.149994          0.850006
# 2022-12-13  418.500000          4.350006
# 2022-12-14  417.899994         -0.600006
#
# [258 rows x 7 columns]

# %%
##prediction
pred_start_date=test_data.index[0]
pred_end_date=test_data.index[-1]
print(pred_start_date)
print(pred_end_date)
# Out:
# 2021-12-02 00:00:00
# 2022-12-14 00:00:00

# %%
pred=model_Arima_fit.predict(start=pred_start_date,end=pred_end_date)
residuals=test_data['Close']-pred

# %%
pred
# Out:
# Date
# 2021-12-02    473.180015
# 2021-12-03    480.663805
# 2021-12-06    478.756976
# 2021-12-07    468.851401
# 2021-12-08    479.821624
#                  ...
# 2022-12-08    420.504605
# 2022-12-09    416.983161
# 2022-12-12    413.641776
# 2022-12-13    413.830345
# 2022-12-14    418.586176
# Name: predicted_mean, Length: 258, dtype: float64

# %%
residuals
# Out:
# Date
# 2021-12-02     5.919991
# 2021-12-03    -0.563798
# 2021-12-06   -11.556964
# 2021-12-07    12.948587
# 2021-12-08    14.078370
#                 ...
# 2022-12-08    -3.304593
# 2022-12-09    -3.683173
# 2022-12-12     0.508218
# 2022-12-13     4.669655
# 2022-12-14    -0.686182
# Length: 258, dtype: float64

# %%
model_Arima_fit.resid.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
test_data['Predicted_ARIMA']=pred
# Out:
# C:\Users\BIPLAB\AppData\Local\Temp\ipykernel_2680\95659616.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['Predicted_ARIMA']=pred

# %%
test_data[['Close','Predicted_ARIMA']].plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
pred
# Out:
# Date
# 2021-12-02    473.180015
# 2021-12-03    480.663805
# 2021-12-06    478.756976
# 2021-12-07    468.851401
# 2021-12-08    479.821624
#                  ...
# 2022-12-08    420.504605
# 2022-12-09    416.983161
# 2022-12-12    413.641776
# 2022-12-13    413.830345
# 2022-12-14    418.586176
# Name: predicted_mean, Length: 258, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
rmse= sqrt(mean_squared_error(pred,test_data['Close']))
rmse
# Out:
# 9.922922525959684

# %%
test_data['Close'].mean()
# as rmse is very lesser than mean then our model is a good model
# Out:
# 443.69011623175567

# %%
##prediction
pred_start_date=test_data.index[-1]
pred_end_date='2023-02-20 00:00:00'
print(pred_start_date)
print(pred_end_date)
# Out:
# 2022-12-14 00:00:00
# 2023-02-20 00:00:00

# %%
index_future_dates = pd.date_range(start='2022-12-14',end='2023-02-20')
pred1=model_Arima_fit.predict(start=len(df1),end=len(df1)+68)
pred1.index=index_future_dates
# residuals1=test_data['Close']-pred1
# Out:
# C:\Users\BIPLAB\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
pred1
# Out:
# 2022-12-14    417.853076
# 2022-12-15    417.894070
# 2022-12-16    417.858252
# 2022-12-17    417.889547
# 2022-12-18    417.862203
#                  ...
# 2023-02-16    417.874950
# 2023-02-17    417.874957
# 2023-02-18    417.874951
# 2023-02-19    417.874957
# 2023-02-20    417.874952
# Freq: D, Name: predicted_mean, Length: 69, dtype: float64

# %%
pred1.plot()
# Out:
# <AxesSubplot:>

# %%
model2=ARIMA(df1['Close'],order=(1,1,1))
model2=model2.fit()
df1.tail()
# Out:
# C:\Users\BIPLAB\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\BIPLAB\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\BIPLAB\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\BIPLAB\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\BIPLAB\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#                   High         Low        Open       Close   Volume  \
# Date
# 2022-12-08  421.399994  415.350006  421.000000  417.200012  9539923
# 2022-12-09  420.950012  409.549988  419.299988  413.299988  9920219
# 2022-12-12  416.899994  408.000000  412.000000  414.149994  8009229
# 2022-12-13  421.500000  417.250000  419.950012  418.500000  9717894
# 2022-12-14  421.350006  417.350006  420.549988  417.899994  6312970
#
#              Adj Close  first_diff_Close
# Date
# 2022-12-08  417.200012         -2.899994
# 2022-12-09  413.299988         -3.900024
# 2022-12-12  414.149994          0.850006
# 2022-12-13  418.500000          4.350006
# 2022-12-14  417.899994         -0.600006

# %%
index_future_dates=pd.date_range(start='2022-12-14',end='2023-01-31')
pred2=model2.predict(start=len(df1),end=len(df1)+48,typ='levels').rename('ARIMA Predictions')
pred2.index=index_future_dates
# Out:
# C:\Users\BIPLAB\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
pred2.plot()
# Out:
# <AxesSubplot:>

# %%
zsfczv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2680\3889612960.py in <module>
# ----> 1 zsfczv
#
# NameError: name 'zsfczv' is not defined

# %% [markdown]
# # automate the process

# %%
from pmdarima import auto_arima
import warnings
warnings.filterwarnings('ignore')

# %%
stepwise_fit=auto_arima(df1['Close'], trace=True, suppress_warnings=True)
stepwise_fit.summary()

# %%
#best value od p,d,q --> (1,1,2)

# %%
model_ARIMA_best=ARIMA(df1['Close'],order=(1,1,2))

# %%
model_Arima_fit_best=model_ARIMA_best.fit()

# %%
model_Arima_fit_best.summary()

# %%
test_data

# %%
##prediction
pred_start_date=test_data.index[0]
pred_end_date=test_data.index[-1]
print(pred_start_date)
print(pred_end_date)

# %%
pred_best=model_Arima_fit_best.predict(start=pred_start_date,end=pred_end_date)
residuals_best=test_data['Close']-pred_best

# %%
pred_best

# %%
residuals_best

# %%
model_Arima_fit_best.resid.plot(kind='kde')

# %%
test_data['Predicted_ARIMA']=pred_best

# %%
test_data[['Close','Predicted_ARIMA']].plot(figsize=(15,10))

# %%
pred_best

# %%
rmse_best= sqrt(mean_squared_error(pred_best,test_data['Close']))
rmse_best

# %%
test_data['Close'].mean()

# %%
##prediction
pred_start_date=test_data.index[-1]
pred_end_date='2022-12-31 00:00:00'
print(pred_start_date)
print(pred_end_date)

# %%
index_future_dates = pd.date_range(start='2022-11-11',end='2022-11-21')
pred1_best=model_Arima_fit_best.predict(start=len(df1),end=len(df1)+10)
pred1_best.index=index_future_dates
# residuals1=test_data['Close']-pred1

# %%
pred1_best

# %%
pred1_best.plot()

# %% [markdown]
# # USING MACHINE LEARNING

# %%
X = df1[["Open", "High", "Low", "Adj Close"]]
Y = df1["Close"]
X = X.to_numpy()
Y = Y.to_numpy()
Y = Y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
X_train=ss.fit_transform(X_train)
X_test=ss.transform(X_test)

# %%
def create_model(model):
    model.fit(X_train,Y_train)
    Y_pred=model.predict(X_test)
#find the mean squared error
    print("Root Mean Squared error : ",sqrt(mean_squared_error(Y_test,Y_pred)))
#find the r2_score
    print("R2 Score : ",r2_score(Y_test,Y_pred))
    print("Training score : ",model.score(X_train,Y_train))
    print("Testing score : ",model.score(X_test,Y_test))
    return model,Y_pred

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
#create object of LinearRegression class
lr=LinearRegression()

# %%
lr,Y_pred=create_model(lr)

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt,Y_pred=create_model(dt)

# %%
from sklearn.svm import SVR
svr = SVR()
svr,Y_pred=create_model(svr)

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(max_depth=3)
rfr,Y_pred=create_model(rfr)

# %%
a=pd.DataFrame(Y_pred)
a

# %%
a.plot(figsize=(10,5))

# %%
df2 = df1["Close"]
len(df2)

# %%
train=df2.iloc[:1000]
test=df2.iloc[1000:]

# %%
test

# %%
df1=df1.iloc[1:]

# %%
X = df1.drop(['Close'], axis=1)
y = df1['Close']

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X.head()
# Out:
#        High       Low      Open    Volume  Adj Close  first_diff_Close
# 0  0.730098  0.713300  0.715131  0.006409   0.732494          0.368246
# 1  0.755215  0.752819  0.733090  0.017579   0.763257          0.468912
# 2  0.768093  0.778872  0.764491  0.021459   0.768635          0.381569
# 3  0.764474  0.779529  0.768900  0.005195   0.764763          0.349741
# 4  0.765219  0.782485  0.764706  0.006381   0.767344          0.371947

# %%
#now lets split data in test train pairs

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle=False)

Acc = []

# %%
from sklearn.linear_model import LinearRegression

# model training

model_1 = LinearRegression()
model_1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# prediction
y_pred_1 = model_1.predict(X_test)
pred_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_1})
pred_df.head()
# Out:
#                 Actual   Predicted
# Date
# 2021-12-17  470.200012  470.200012
# 2021-12-20  447.049988  447.049988
# 2021-12-21  453.600006  453.600006
# 2021-12-22  470.500000  470.500000
# 2021-12-23  472.350006  472.350006

# %%
# Measure the Accuracy Score

from sklearn.metrics import r2_score
 
print("Accuracy score of the predictions: {0}".format(r2_score(y_test, y_pred_1)))
Acc.append(r2_score(y_test, y_pred_1))
#Accuracy score of the predictions: 0.9931342019332019
# Out:
# Accuracy score of the predictions: 1.0

# %%
plt.figure(figsize=(8,8))
plt.ylabel('Close Price', fontsize=16)
plt.plot(pred_df)
plt.legend(['Actual Value', 'Predictions'])
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor
model_2 = DecisionTreeRegressor()
model_2.fit(X_train, y_train)

# prediction
y_pred_2 = model_2.predict(X_test)
pred_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_2})
pred_df.head()

# Measure the Accuracy Score
from sklearn.metrics import r2_score
 
print("Accuracy score of the predictions: {0}".format(r2_score(y_test, y_pred_2)))
Acc.append(r2_score(y_test, y_pred_2))
# Out:
# Accuracy score of the predictions: 0.9878974605869607

# %%
plt.figure(figsize=(8,8))
plt.ylabel('Close Price', fontsize=16)
plt.plot(pred_df)
plt.legend(['Actual Value', 'Predictions'])
plt.show()
