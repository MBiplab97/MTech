# %% [markdown]
# **PANDAS**

# %%
import pandas as pd

# %%
df= pd.read_csv("mtcars.csv")
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df["mpg"].max()
# Out:
# 33.9

# %%
df["mpg"][df['cyl']==6][df['wt']==2.620]
# Out:
# 0    21.0
# Name: mpg, dtype: float64

# %%
df.shape
# Out:
# (32, 12)

# %%
rows,column = df.shape

# %%
rows
# Out:
# 32

# %%
column
# Out:
# 12

# %%
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.tail()
# Out:
#              model   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1     4
#
#     carb
# 27     2
# 28     4
# 29     6
# 30     8
# 31     2

# %%
df.tail(3)
# Out:
#             model   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 29   Ferrari Dino  19.7    6  145.0  175  3.62  2.77  15.5   0   1     5     6
# 30  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5     8
# 31     Volvo 142E  21.4    4  121.0  109  4.11  2.78  18.6   1   1     4     2

# %%
df[2:5]
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 2     1
# 3     1
# 4     2

# %%
df.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
df.model
# Out:
# 0               Mazda RX4
# 1           Mazda RX4 Wag
# 2              Datsun 710
# 3          Hornet 4 Drive
# 4       Hornet Sportabout
# 5                 Valiant
# 6              Duster 360
# 7               Merc 240D
# 8                Merc 230
# 9                Merc 280
# 10              Merc 280C
# 11             Merc 450SE
# 12             Merc 450SL
# 13            Merc 450SLC
# 14     Cadillac Fleetwood
# 15    Lincoln Continental
# 16      Chrysler Imperial
# 17               Fiat 128
# 18            Honda Civic
# 19         Toyota Corolla
# 20          Toyota Corona
# 21       Dodge Challenger
# 22            AMC Javelin
# 23             Camaro Z28
# 24       Pontiac Firebird
# 25              Fiat X1-9
# 26          Porsche 914-2
# 27           Lotus Europa
# 28         Ford Pantera L
# 29           Ferrari Dino
# 30          Maserati Bora
# 31             Volvo 142E
# Name: model, dtype: object

# %%
df[['model','wt']]
# Out:
#                   model     wt
# 0             Mazda RX4  2.620
# 1         Mazda RX4 Wag  2.875
# 2            Datsun 710  2.320
# 3        Hornet 4 Drive  3.215
# 4     Hornet Sportabout  3.440
# 5               Valiant  3.460
# 6            Duster 360  3.570
# 7             Merc 240D  3.190
# 8              Merc 230  3.150
# 9              Merc 280  3.440
# 10            Merc 280C  3.440
# 11           Merc 450SE  4.070
# 12           Merc 450SL  3.730
# 13          Merc 450SLC  3.780
# 14   Cadillac Fleetwood  5.250
# 15  Lincoln Continental  5.424
# 16    Chrysler Imperial  5.345
# 17             Fiat 128  2.200
# 18          Honda Civic  1.615
# 19       Toyota Corolla  1.835
# 20        Toyota Corona  2.465
# 21     Dodge Challenger  3.520
# 22          AMC Javelin  3.435
# 23           Camaro Z28  3.840
# 24     Pontiac Firebird  3.845
# 25            Fiat X1-9  1.935
# 26        Porsche 914-2  2.140
# 27         Lotus Europa  1.513
# 28       Ford Pantera L  3.170
# ...

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=32, step=1)

# %%
#   df1=df.to_csv("x.csv")  --this is how we can store our fina dataset n csv format into computer

# %%
df =pd.read_csv('mtcars.csv',skiprows = 5)
df
# Out:
#       Hornet Sportabout  18.7  8    360  175  3.15   3.44  17.02  0  0.1  3  2
# 0               Valiant  18.1  6  225.0  105  2.76  3.460  20.22  1    0  3  1
# 1            Duster 360  14.3  8  360.0  245  3.21  3.570  15.84  0    0  3  4
# 2             Merc 240D  24.4  4  146.7   62  3.69  3.190  20.00  1    0  4  2
# 3              Merc 230  22.8  4  140.8   95  3.92  3.150  22.90  1    0  4  2
# 4              Merc 280  19.2  6  167.6  123  3.92  3.440  18.30  1    0  4  4
# 5             Merc 280C  17.8  6  167.6  123  3.92  3.440  18.90  1    0  4  4
# 6            Merc 450SE  16.4  8  275.8  180  3.07  4.070  17.40  0    0  3  3
# 7            Merc 450SL  17.3  8  275.8  180  3.07  3.730  17.60  0    0  3  3
# 8           Merc 450SLC  15.2  8  275.8  180  3.07  3.780  18.00  0    0  3  3
# 9    Cadillac Fleetwood  10.4  8  472.0  205  2.93  5.250  17.98  0    0  3  4
# 10  Lincoln Continental  10.4  8  460.0  215  3.00  5.424  17.82  0    0  3  4
# ...

# %%
import pandas as pd
import numpy as np
x = np.array([[1, 2], [3, 4], [2, 2], [9, 6]])

# %%
print(np.sum(x,axis=1))
# Out:
# [ 3  7  4 15]

# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('matches.csv')
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data5=pd.read_csv('deliveries.csv')
data5
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
mask=data5['batsman_runs']==6
new=data5[mask]

four=new.groupby('batsman')

four['batsman_runs'].count().sort_values(ascending=False).head()
# Out:
# batsman
# CH Gayle     266
# SK Raina     174
# RG Sharma    173
# V Kohli      160
# DA Warner    160
# Name: batsman_runs, dtype: int64

# %%
mask1=data5['batsman']=='V Kohli'
new1=data5[mask1]
new2=new1.groupby('bowling_team')
new2['batsman_runs'].sum().sort_values(ascending=False).head()
# Out:
# bowling_team
# Chennai Super Kings    706
# Delhi Daredevils       661
# Kings XI Punjab        483
# Mumbai Indians         447
# Sunrisers Hyderabad    439
# Name: batsman_runs, dtype: int64

# %%
dataset=[12,15,14,100,17,19,2,30,31,27,25,26,19,99,85,110,14,15,16,25,16,17,18,34,35,39]
data=np.array(dataset)
m=np.mean(data)
print(m)
s=np.std(data)
s
for i in dataset:
    z_score=(i-m)/s
    if np.abs(z_score)>3:
        prnt(i)
# Out:
# 33.07692307692308
